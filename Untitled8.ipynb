# %% [markdown]
# <a href="https://colab.research.google.com/github/Anushka157-cha/Pipeline1/blob/main/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a1143342-7db3-490c-9b68-dddfe66798cc" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a1143342-7db3-490c-9b68-dddfe66798cc">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s sipakmed
# Out:
# You must authenticate before you can call the Kaggle API.
# Follow the instructions to authenticate at: https://github.com/Kaggle/kaggle-cli/blob/main/docs/README.md#authentication

# %%
# !ls ~/.kaggle
# Out:
# ls: cannot access '/root/.kaggle': No such file or directory

# %%
# !mkdir -p /root/.kaggle

# !cp "kaggle (1).json" /root/.kaggle/kaggle.json

# !chmod 600 /root/.kaggle/kaggle.json

# !ls /root/.kaggle
# Out:
# kaggle.json

# %%
# !kaggle datasets list -s sipakmed
# Out:
# ref                                                           title                                              size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ------------------------------------------------------------  ------------------------------------------  -----------  --------------------------  -------------  ---------  ---------------
# prahladmehandiratta/cervical-cancer-largest-dataset-sipakmed  Cervical Cancer largest dataset (SipakMed)   6875604663  2021-03-12 23:21:45.757000          15749        161  0.75
# marinaeplissiti/sipakmed                                      SIPaKMeD                                     6875604663  2023-03-27 08:41:05.853000            917          6  0.75
# mohaliy2016/papsinglecell                                     Single Cell Conventional Pap Smear Images     422721578  2020-03-25 15:29:09.723000            773         10  0.8125
# ...

# %%
# !kaggle datasets download -d prahladmehandiratta/cervical-cancer-largest-dataset-sipakmed
# Out:
# Dataset URL: https://www.kaggle.com/datasets/prahladmehandiratta/cervical-cancer-largest-dataset-sipakmed
# License(s): other
# ...
# 100% 6.40G/6.40G [00:47<00:00, 145MB/s]

# %%
# !ls -lh /content
# Out:
# total 6.5G
# -rw-r--r-- 1 root root 6.5G Mar 12  2021  cervical-cancer-largest-dataset-sipakmed.zip
# -rw-r--r-- 1 root root   69 Jun  7 07:45 'kaggle (1).json'
# drwxr-xr-x 1 root root 4.0K Jun  4 13:39  sample_data

# %%
# !unzip -o "/content/cervical-cancer-largest-dataset-sipakmed.zip" -d "/content/sipakmed"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_12_cyt.dat
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_12_nuc.dat
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_13.bmp
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_13_cyt.dat
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_13_nuc.dat
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_14.bmp
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_14_cyt.dat
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/075_14_nuc.dat
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/076_01.bmp
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/076_01_cyt.dat
#   inflating: /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED/076_01_nuc.dat
# ...

# %%
# !find /content/sipakmed -maxdepth 3 -type d
# Out:
# /content/sipakmed
# /content/sipakmed/im_Koilocytotic
# /content/sipakmed/im_Koilocytotic/im_Koilocytotic
# /content/sipakmed/im_Koilocytotic/im_Koilocytotic/CROPPED
# /content/sipakmed/im_Dyskeratotic
# /content/sipakmed/im_Dyskeratotic/im_Dyskeratotic
# /content/sipakmed/im_Dyskeratotic/im_Dyskeratotic/CROPPED
# /content/sipakmed/im_Metaplastic
# /content/sipakmed/im_Metaplastic/im_Metaplastic
# /content/sipakmed/im_Metaplastic/im_Metaplastic/CROPPED
# /content/sipakmed/im_Parabasal
# /content/sipakmed/im_Parabasal/im_Parabasal
# /content/sipakmed/im_Parabasal/im_Parabasal/CROPPED
# /content/sipakmed/im_Superficial-Intermediate
# /content/sipakmed/im_Superficial-Intermediate/im_Superficial-Intermediate
# /content/sipakmed/im_Superficial-Intermediate/im_Superficial-Intermediate/CROPPED

# %%
import os
import shutil
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
import os
import shutil

TARGET = "/content/SIPAKMED_FINAL"

classes = {
    "Dyskeratotic":
    "/content/sipakmed/im_Dyskeratotic/im_Dyskeratotic/CROPPED",

    "Koilocytotic":
    "/content/sipakmed/im_Koilocytotic/im_Koilocytotic/CROPPED",

    "Metaplastic":
    "/content/sipakmed/im_Metaplastic/im_Metaplastic/CROPPED",

    "Parabasal":
    "/content/sipakmed/im_Parabasal/im_Parabasal/CROPPED",

    "SuperficialIntermediate":
    "/content/sipakmed/im_Superficial-Intermediate/im_Superficial-Intermediate/CROPPED"
}

os.makedirs(TARGET, exist_ok=True)

for cls, src in classes.items():

    dst = os.path.join(TARGET, cls)

    os.makedirs(dst, exist_ok=True)

    for img in os.listdir(src):
        shutil.copy(
            os.path.join(src, img),
            os.path.join(dst, img)
        )

print("Dataset Organized Successfully")
# Out:
# Dataset Organized Successfully

# %%
for cls in os.listdir("/content/SIPAKMED_FINAL"):

    count = len(
        os.listdir(
            os.path.join(
                "/content/SIPAKMED_FINAL",
                cls
            )
        )
    )

    print(cls, count)
# Out:
# Parabasal 2361
# SuperficialIntermediate 2493
# Dyskeratotic 2439
# Metaplastic 2379
# Koilocytotic 2475

# %%
IMG_SIZE = (300,300)

BATCH_SIZE = 32

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/SIPAKMED_FINAL",
    validation_split=0.2,
    subset="training",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)

val_ds = tf.keras.utils.image_dataset_from_directory(
    "/content/SIPAKMED_FINAL",
    validation_split=0.2,
    subset="validation",
    seed=42,
    image_size=IMG_SIZE,
    batch_size=BATCH_SIZE
)
# Out:
# Found 4049 files belonging to 5 classes.
# Using 3240 files for training.
# Found 4049 files belonging to 5 classes.
# Using 809 files for validation.

# %%
print(train_ds.class_names)
# Out:
# ['Dyskeratotic', 'Koilocytotic', 'Metaplastic', 'Parabasal', 'SuperficialIntermediate']

# %%
plt.figure(figsize=(10,10))

for images, labels in train_ds.take(1):

    for i in range(9):

        ax = plt.subplot(3,3,i+1)

        plt.imshow(images[i].numpy().astype("uint8"))

        plt.title(
            train_ds.class_names[
                labels[i]
            ]
        )

        plt.axis("off")

plt.show()

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip("horizontal"),
    tf.keras.layers.RandomRotation(0.2),
    tf.keras.layers.RandomZoom(0.2),
    tf.keras.layers.RandomContrast(0.2)
])

# %%
from tensorflow.keras.applications import EfficientNetB3

base_model = EfficientNetB3(
    weights='imagenet',
    include_top=False,
    input_shape=(300,300,3)
)

base_model.trainable = False
# Out:
# ...
# 43941136/43941136 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
from tensorflow.keras.applications import EfficientNetB3
from tensorflow.keras import layers, Model

base_model = EfficientNetB3(
    weights="imagenet",
    include_top=False,
    input_shape=(300,300,3)
)

base_model.trainable = False

inputs = tf.keras.Input(shape=(300,300,3))

x = data_augmentation(inputs)
x = tf.keras.applications.efficientnet.preprocess_input(x)

x = base_model(x)

x = layers.GlobalAveragePooling2D()(x)
x = layers.Dropout(0.3)(x)

outputs = layers.Dense(5, activation="softmax")(x)

model = Model(inputs, outputs)

print("MODEL CREATED SUCCESSFULLY")
# Out:
# MODEL CREATED SUCCESSFULLY

# %%
print(model)
print(base_model)
# Out:
# <Functional name=functional_1, built=True>
# <Functional name=efficientnetb3, built=True>

# %%
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# %%
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=15
)
# Out:
# Epoch 1/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 58s 357ms/step - accuracy: 0.6994 - loss: 0.8848 - val_accuracy: 0.7960 - val_loss: 0.5701
# Epoch 2/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 31s 308ms/step - accuracy: 0.8315 - loss: 0.5221 - val_accuracy: 0.8492 - val_loss: 0.4450
# Epoch 3/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 33s 322ms/step - accuracy: 0.8432 - loss: 0.4583 - val_accuracy: 0.8653 - val_loss: 0.3853
# Epoch 4/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 34s 330ms/step - accuracy: 0.8654 - loss: 0.4040 - val_accuracy: 0.8640 - val_loss: 0.3559
# Epoch 5/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 37s 361ms/step - accuracy: 0.8735 - loss: 0.3685 - val_accuracy: 0.8752 - val_loss: 0.3320
# Epoch 6/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 38s 328ms/step - accuracy: 0.8769 - loss: 0.3495 - val_accuracy: 0.8776 - val_loss: 0.3295
# Epoch 7/15
# 102/102 ━━━━━━━━━━━━━━━━━━━━ 33s 325ms/step - accuracy: 0.8833 - loss: 0.3470 - val_accuracy: 0.8888 - val_loss: 0.3112
# Epoch 8/15
# ...

# %%
import time

start = time.time()

base_model.trainable = True

for layer in base_model.layers[:-30]:
    layer.trainable = False

print("Done")
print(time.time() - start)
# Out:
# Done
# 0.022589445114135742

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# input_layer_2
# sequential
# efficientnetb3
# global_average_pooling2d
# dropout
# dense

# %%
# !pip install -q opencv-python

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

LAST_CONV_LAYER = "top_conv"

grad_model = tf.keras.models.Model(
    inputs=model.inputs,
    outputs=[
        base_model.get_layer(LAST_CONV_LAYER).output,
        model.output
    ]
)

def get_gradcam_heatmap(img_array):

    with tf.GradientTape() as tape:

        conv_outputs, predictions = grad_model(img_array)

        pred_index = tf.argmax(predictions[0])

        class_channel = predictions[:, pred_index]

    grads = tape.gradient(class_channel, conv_outputs)

    pooled_grads = tf.reduce_mean(
        grads,
        axis=(0,1,2)
    )

    conv_outputs = conv_outputs[0]

    heatmap = tf.reduce_sum(
        pooled_grads * conv_outputs,
        axis=-1
    )

    heatmap = tf.maximum(heatmap,0)

    heatmap /= tf.reduce_max(heatmap)

    return heatmap.numpy()

# %%
img_path = "/content/SIPAKMED_FINAL/Koilocytotic/sample.jpg"

# %%
import os

for root, dirs, files in os.walk("/content/SIPAKMED_FINAL"):
    for f in files[:5]:
        print(os.path.join(root, f))
        break
# Out:
# /content/SIPAKMED_FINAL/Parabasal/054_01_nuc.dat
# /content/SIPAKMED_FINAL/SuperficialIntermediate/054_01_nuc.dat
# /content/SIPAKMED_FINAL/Dyskeratotic/054_01_nuc.dat
# /content/SIPAKMED_FINAL/Metaplastic/054_01_nuc.dat
# /content/SIPAKMED_FINAL/Koilocytotic/054_01_nuc.dat

# %%
import os

for root, dirs, files in os.walk("/content/SIPAKMED_FINAL"):
    for f in files:
        print(f)
        break
    break

# %%
import os

for root, dirs, files in os.walk("/content/SIPAKMED_FINAL"):
    for f in files[:20]:
        print(f)
# Out:
# 054_01_nuc.dat
# 055_05_nuc.dat
# 045_03.bmp
# 008_02_cyt.dat
# 100_08_nuc.dat
# 094_07_nuc.dat
# 078_03_nuc.dat
# 101_02_cyt.dat
# 017_02_nuc.dat
# 041_03_cyt.dat
# 047_06.bmp
# 038_05_cyt.dat
# 095_15_nuc.dat
# 019_09.bmp
# 096_09.bmp
# 017_02_cyt.dat
# 049_09.bmp
# 073_02_nuc.dat
# 046_01_nuc.dat
# 051_02.bmp
# 054_01_nuc.dat
# 055_05_nuc.dat
# 045_03.bmp
# 122_02_nuc.dat
# 008_02_cyt.dat
# 094_07_nuc.dat
# 078_03_nuc.dat
# 009_07_cyt.dat
# 101_02_cyt.dat
# 017_02_nuc.dat
# 115_02_cyt.dat
# 041_03_cyt.dat
# 080_08_nuc.dat
# 121_01_nuc.dat
# 019_09.bmp
# 096_09.bmp
# 017_02_cyt.dat
# 073_02_nuc.dat
# 046_01_nuc.dat
# 051_02.bmp
# 054_01_nuc.dat
# 149_01.bmp
# 191_01_nuc.dat
# 211_03_nuc.dat
# 164_12_nuc.dat
# 219_05_cyt.dat
# 198_02.bmp
# 122_02_nuc.dat
# 008_02_cyt.dat
# 163_05.bmp
# 067_19_nuc.dat
# 088_03.bmp
# 141_10.bmp
# 024_08_cyt.dat
# 100_08_nuc.dat
# 067_18_cyt.dat
# 219_10_nuc.dat
# 009_07_cyt.dat
# 212_01_nuc.dat
# 059_13.bmp
# 054_01_nuc.dat
# 149_01.bmp
# 152_03.bmp
# ...

# %%
import os

for root, dirs, files in os.walk("/content/SIPAKMED_FINAL"):
    for f in files:
        if f.endswith(".bmp"):
            img_path = os.path.join(root, f)
            print(img_path)
            break
    else:
        continue
    break
# Out:
# /content/SIPAKMED_FINAL/Parabasal/045_03.bmp

# %%
from PIL import Image
import matplotlib.pyplot as plt

img = Image.open(img_path)

plt.figure(figsize=(5,5))
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
import tensorflow as tf
import numpy as np

img = tf.keras.preprocessing.image.load_img(
    img_path,
    target_size=(300,300)
)

img_array = tf.keras.preprocessing.image.img_to_array(img)

img_array = np.expand_dims(img_array, axis=0)

img_array = tf.keras.applications.efficientnet.preprocess_input(
    img_array
)

print(img_array.shape)
# Out:
# (1, 300, 300, 3)

# %%
# %whos
# Out:
# Variable              Type                Data/Info
# ---------------------------------------------------
# BATCH_SIZE            int                 32
# EfficientNetB3        function            <function EfficientNetB3 at 0x7f3193e88f40>
# IMG_SIZE              tuple               n=2
# Image                 module              <module 'PIL.Image' from <...>t-packages/PIL/Image.py'>
# LAST_CONV_LAYER       str                 top_conv
# Model                 type                <class 'keras.src.models.model.Model'>
# TARGET                str                 /content/SIPAKMED_FINAL
# ax                    Axes                Axes(0.672794,0.11;0.226471x0.226471)
# base_model            Functional          <Functional name=efficientnetb3, built=True>
# classes               dict                n=5
# cls                   str                 Koilocytotic
# count                 int                 2475
# ...

# %%
print(model.input)
print(model.output)

print(base_model.input)
print(base_model.output)
# Out:
# <KerasTensor shape=(None, 300, 300, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor_770>
# <KerasTensor shape=(None, 5), dtype=float32, sparse=False, ragged=False, name=keras_tensor_780>
# <KerasTensor shape=(None, 300, 300, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor_385>
# <KerasTensor shape=(None, 10, 10, 1536), dtype=float32, sparse=False, ragged=False, name=keras_tensor_769>

# %%
print(model.input_shape)
print(model.output_shape)
# Out:
# (None, 300, 300, 3)
# (None, 5)

# %%
del grad_model
print("Old grad_model deleted")
# Out:
# Old grad_model deleted

# %%
for layer in base_model.layers[-20:]:
    print(layer.name)
# Out:
# block7a_project_conv
# block7a_project_bn
# block7b_expand_conv
# block7b_expand_bn
# block7b_expand_activation
# block7b_dwconv
# block7b_bn
# block7b_activation
# block7b_se_squeeze
# block7b_se_reshape
# block7b_se_reduce
# block7b_se_expand
# block7b_se_excite
# block7b_project_conv
# block7b_project_bn
# block7b_drop
# block7b_add
# top_conv
# top_bn
# top_activation

# %%
print(model.input_shape)
print(model.output_shape)

pred = model.predict(img_array)

print(pred.shape)
print(pred)
# Out:
# (None, 300, 300, 3)
# (None, 5)
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 4s 4s/step
# (1, 5)
# [[1.1662662e-03 5.9389957e-04 1.1265801e-03 9.9679059e-01 3.2262088e-04]]

# %%
print(model.inputs)
print(model.outputs)
# Out:
# [<KerasTensor shape=(None, 300, 300, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor_770>]
# [<KerasTensor shape=(None, 5), dtype=float32, sparse=False, ragged=False, name=keras_tensor_780>]

# %%
preds = model.predict(img_array)

print("Shape:", preds.shape)
print("Prediction:", preds)
print("Predicted Class:", np.argmax(preds[0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# Shape: (1, 5)
# Prediction: [[1.1662662e-03 5.9389957e-04 1.1265801e-03 9.9679059e-01 3.2262088e-04]]
# Predicted Class: 3

# %%
feature_extractor = tf.keras.Model(
    inputs=base_model.input,
    outputs=base_model.get_layer("top_conv").output
)

conv_features = feature_extractor(img_array)

print(conv_features.shape)
# Out:
# (1, 10, 10, 1536)

# %%
preds = model.predict(img_array)

print(preds)
print("Predicted Class:", np.argmax(preds[0]))
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step
# [[1.1662662e-03 5.9389957e-04 1.1265801e-03 9.9679059e-01 3.2262088e-04]]
# Predicted Class: 3

# %%
grad_model = tf.keras.models.Model(
    inputs=model.inputs,
    outputs=[
        model.get_layer("efficientnetb3").get_layer("top_conv").output,
        model.output
    ]
)

print("Grad model created")
# Out:
# Grad model created

# %%
print(type(img_array))
print(img_array.shape)

img_tensor = tf.convert_to_tensor(img_array, dtype=tf.float32)

print(type(img_tensor))
print(img_tensor.shape)
# Out:
# <class 'numpy.ndarray'>
# (1, 300, 300, 3)
# <class 'tensorflow.python.framework.ops.EagerTensor'>
# (1, 300, 300, 3)

# %%
for i, layer in enumerate(model.layers):
    print(i, layer.name, type(layer))
# Out:
# 0 input_layer_2 <class 'keras.src.layers.core.input_layer.InputLayer'>
# 1 sequential <class 'keras.src.models.sequential.Sequential'>
# 2 efficientnetb3 <class 'keras.src.models.functional.Functional'>
# 3 global_average_pooling2d <class 'keras.src.layers.pooling.global_average_pooling2d.GlobalAveragePooling2D'>
# 4 dropout <class 'keras.src.layers.regularization.dropout.Dropout'>
# 5 dense <class 'keras.src.layers.core.dense.Dense'>

# %%
model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)      │ (None, 300, 300, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ sequential (Sequential)         │ (None, 300, 300, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb3 (Functional)     │ (None, 10, 10, 1536)   │    10,783,535 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1536)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# ...

# %%
print(base_model.input)
print(base_model.output)
# Out:
# <KerasTensor shape=(None, 300, 300, 3), dtype=float32, sparse=False, ragged=False, name=keras_tensor_385>
# <KerasTensor shape=(None, 10, 10, 1536), dtype=float32, sparse=False, ragged=False, name=keras_tensor_769>

# %%
feature_extractor = tf.keras.Model(
    inputs=base_model.input,
    outputs=base_model.output
)

conv_features = feature_extractor(img_array, training=False)

print(conv_features.shape)
# Out:
# (1, 10, 10, 1536)

# %%
import tensorflow as tf
import numpy as np
import cv2
import matplotlib.pyplot as plt

# -------- Feature maps --------
feature_extractor = tf.keras.Model(
    inputs=base_model.input,
    outputs=base_model.output
)

# -------- Classifier Head --------
classifier_input = tf.keras.Input(shape=(10,10,1536))

x = model.layers[3](classifier_input)   # GAP
x = model.layers[4](x)                  # Dropout
classifier_output = model.layers[5](x)  # Dense

classifier = tf.keras.Model(
    classifier_input,
    classifier_output
)

with tf.GradientTape() as tape:

    conv_outputs = feature_extractor(img_array)

    tape.watch(conv_outputs)

    preds = classifier(conv_outputs, training=False)

    pred_index = tf.argmax(preds[0])

    class_score = preds[:, pred_index]

grads = tape.gradient(class_score, conv_outputs)

print("Gradient None?", grads is None)

pooled_grads = tf.reduce_mean(
    grads,
    axis=(0,1,2)
)

conv_outputs = conv_outputs[0]

heatmap = tf.reduce_sum(
    conv_outputs * pooled_grads,
    axis=-1
)

heatmap = tf.maximum(heatmap, 0)

heatmap /= (
    tf.reduce_max(heatmap) + 1e-8
)

heatmap = heatmap.numpy()

print("Heatmap Shape:", heatmap.shape)
# Out:
# Gradient None? False
# Heatmap Shape: (10, 10)

# %%
model.save("/content/efficientnetb3_sipakmed.keras")

# %%
plt.imshow(heatmap)
plt.title("Grad-CAM Heatmap")
plt.show()

# %%
img = cv2.imread(img_path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
heatmap_resized = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
heatmap_uint8 = np.uint8(255 * heatmap_resized)

heatmap_color = cv2.applyColorMap(heatmap_uint8, cv2.COLORMAP_JET)
heatmap_color = cv2.cvtColor(heatmap_color, cv2.COLOR_BGR2RGB)

# %%
overlay = cv2.addWeighted(img, 0.6, heatmap_color, 0.4, 0)

# %%
import matplotlib.pyplot as plt

plt.imshow(overlay)
plt.title("Grad-CAM Overlay")
plt.axis("off")
plt.show()

# %%
last_conv_layer = "block7a_project_conv"  # deeper layer try karo

# %%
# !pip install shap

# %%
import shap
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# %%
# take small batch from train dataset
for images, labels in train_ds.take(1):
    background = images[:20]   # 20 images enough

# %%
explainer = shap.GradientExplainer(model, background)

# %%
test_img = img_array   # already (1,300,300,3)

# %%
shap_values = explainer.shap_values(test_img)
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_770
# Received: inputs=['Tensor(shape=(1, 300, 300, 3))']
#   warnings.warn(msg)
# /usr/local/lib/python3.12/dist-packages/keras/src/models/functional.py:241: UserWarning: The structure of `inputs` doesn't match the expected structure.
# Expected: keras_tensor_770
# Received: inputs=['Tensor(shape=(50, 300, 300, 3))']
#   warnings.warn(msg)

# %%
shap.image_plot(shap_values, test_img)
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [65.0..196.0].
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers). Got range [-4.147295840084553e-09..4.059984348714352e-09].

# %%
pred = model.predict(test_img)
print("Predicted Class:", list(classes.keys())[np.argmax(pred)])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step
# Predicted Class: Parabasal

# %%
cv2.imwrite("gradcam.png", overlay)
# Out:
# True

# %%
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
def load_image(path):
    img = cv2.imread(path)

    if img is None:
        # fallback for weird formats
        import PIL.Image as Image
        img = np.array(Image.open(path).convert("RGB"))

    img = cv2.resize(img, (300, 300))
    return img

# %%
def preprocess(img):
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

    blur = cv2.GaussianBlur(gray, (5,5), 0)

    _, thresh = cv2.threshold(
        blur, 0, 255,
        cv2.THRESH_BINARY + cv2.THRESH_OTSU
    )

    return gray, thresh

# %%
def extract_features(img_path, label):

    img = load_image(img_path)

    gray, thresh = preprocess(img)

    contours, _ = cv2.findContours(
        thresh,
        cv2.RETR_EXTERNAL,
        cv2.CHAIN_APPROX_SIMPLE
    )

    if len(contours) == 0:
        return None

    cnt = max(contours, key=cv2.contourArea)

    # -------- FEATURES -------- #

    area = cv2.contourArea(cnt)

    perimeter = cv2.arcLength(cnt, True)

    x,y,w,h = cv2.boundingRect(cnt)

    aspect_ratio = float(w)/h if h != 0 else 0

    circularity = 4*np.pi*(area/(perimeter**2 + 1e-8))

    # Hu Moments (shape descriptor)
    moments = cv2.moments(cnt)
    hu = cv2.HuMoments(moments).flatten()

    feature_vector = {
        "label": label,
        "area": area,
        "perimeter": perimeter,
        "aspect_ratio": aspect_ratio,
        "circularity": circularity,
        "hu1": hu[0],
        "hu2": hu[1],
        "hu3": hu[2],
        "hu4": hu[3],
        "hu5": hu[4],
        "hu6": hu[5],
        "hu7": hu[6],
    }

    return feature_vector

# %%
dataset_path = "/content/SIPAKMED_FINAL"

data = []

for class_name in os.listdir(dataset_path):
    class_path = os.path.join(dataset_path, class_name)

    for img_name in os.listdir(class_path):

        img_path = os.path.join(class_path, img_name)

        try:
            features = extract_features(img_path, class_name)

            if features is not None:
                data.append(features)

        except:
            pass

df = pd.DataFrame(data)

df.head()
# Out:
#        label     area    perimeter  aspect_ratio  circularity       hu1  \
# 0  Parabasal  57310.5  1675.619398      1.000000     0.256504  0.243400
# 1  Parabasal  28810.0  1056.499561      2.272727     0.324350  0.315553
# 2  Parabasal  48567.0  1927.518893      1.000000     0.164268  0.377998
# 3  Parabasal  87445.0  1222.225396      1.000000     0.735601  0.168650
# 4  Parabasal  86620.0  1268.936072      1.000000     0.676003  0.169993
#
#         hu2       hu3           hu4           hu5           hu6           hu7
# 0  0.007734  0.003660  4.457097e-04  4.046045e-08 -1.962055e-05 -5.678068e-07
# 1  0.064699  0.000765  1.673224e-04  1.522312e-08  3.076113e-06 -5.789917e-08
# 2  0.005812  0.001923  4.293484e-03 -1.112323e-05 -3.010514e-04 -5.338216e-06
# 3  0.000026  0.000006  9.016088e-07 -2.043419e-12 -4.624846e-09 -2.592661e-13
# 4  0.000023  0.000004  2.121004e-06 -5.975506e-12 -1.007111e-08 -2.457516e-12

# %%
df.to_csv("morphology_features.csv", index=False)
print("Saved morphology_features.csv")
# Out:
# Saved morphology_features.csv

# %%
import seaborn as sns

plt.figure(figsize=(8,5))
sns.boxplot(x="label", y="area", data=df)
plt.title("Cell Area Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
pred_class = list(classes.keys())[np.argmax(model.predict(test_img))]

row = df.iloc[0]  # morphology features (example row)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step

# %%
summary = f"""
Cell Analysis Report:

- Area: {row['area']:.2f}
- Perimeter: {row['perimeter']:.2f}
- Circularity: {row['circularity']:.2f}
- Aspect Ratio: {row['aspect_ratio']:.2f}
"""
print(summary)
# Out:
# Cell Analysis Report:
#
# - Area: 57310.50
# - Perimeter: 1675.62
# - Circularity: 0.26
# - Aspect Ratio: 1.00

# %%
def generate_report(pred_class, row):

    report = f"""
    🔬 Cervical Cell Analysis Report

    🧠 Prediction:
    The model classifies the cell as {pred_class}.

    📊 Morphology Analysis:
    - Cell area is {row['area']:.2f}, indicating {'large' if row['area'] > 50000 else 'moderate/small'} nuclear structure.
    - Circularity is {row['circularity']:.2f}, suggesting {'regular' if row['circularity'] > 0.5 else 'irregular'} shape morphology.
    - Aspect ratio is {row['aspect_ratio']:.2f}, indicating cell elongation characteristics.

    🧬 Interpretation:
    The morphological features combined with deep learning prediction suggest characteristics consistent with {pred_class} cell type.

    ⚠️ Note:
    This is an AI-assisted diagnostic suggestion and should be validated by medical experts.
    """

    return report

report = generate_report(pred_class, row)
print(report)
# Out:
#     🔬 Cervical Cell Analysis Report
#
#     🧠 Prediction:
#     The model classifies the cell as Parabasal.
#
#     📊 Morphology Analysis:
#     - Cell area is 57310.50, indicating large nuclear structure.
#     - Circularity is 0.26, suggesting irregular shape morphology.
#     - Aspect ratio is 1.00, indicating cell elongation characteristics.
#
#     🧬 Interpretation:
#     The morphological features combined with deep learning prediction suggest characteristics consistent with Parabasal cell type.
#
#     ⚠️ Note:
#     This is an AI-assisted diagnostic suggestion and should be validated by medical experts.

# %%
with open("medical_report.txt", "w") as f:
    f.write(report)

print("Report saved!")
# Out:
# Report saved!
